# %% [markdown]
# # Toy Dataset Tester

# %%
# LOAD DATASET

import pandas as pd

url = "https://raw.githubusercontent.com/jparisu/CUNEF-Resources/refs/heads/main/datasets/game/1.csv"

df = pd.read_csv(url)
df_X = df.drop(columns=df.columns[-1])
df_y = df[df.columns[-1]]

# %% [markdown]
# ---

# %%
# PREDICT

def predict(df_X):
    # Implement your prediction logic here

    # For demonstration purposes, let's return a dummy prediction
    return [0] * len(df_X)

# %% [markdown]
# ---

# %%
# TEST

# Predict over dataset
predictions = predict(df_X)
# Compare predictions
print(list(zip(predictions, df_y)))

# Evaluate predictions (accuracy)
accuracy = sum(predictions == df_y) / len(df_y)
print(f"Accuracy: {accuracy:.2f}")
